# %% [markdown]
# # paraphrase

# %%
import torch
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

tokenizer = AutoTokenizer.from_pretrained("humarin/chatgpt_paraphraser_on_T5_base")
# device = torch.device("mps" if torch.backends.mps.is_available() else "cpu") # This always results in MPS
device = "cpu"

model = AutoModelForSeq2SeqLM.from_pretrained("humarin/chatgpt_paraphraser_on_T5_base").to(device)

# %%
def paraphrase(
    question,
    num_beams=5,
    num_beam_groups=5,
    num_return_sequences=5,
    repetition_penalty=10.0,
    diversity_penalty=3.0,
    no_repeat_ngram_size=2,
    temperature=0.7,
    max_length=128
):
    input_ids = tokenizer(
        f'paraphrase: {question}',
        return_tensors="pt", padding="longest",
        max_length=max_length,
        truncation=True,
    ).input_ids
    
    outputs = model.generate(
        input_ids, temperature=temperature, repetition_penalty=repetition_penalty,
        num_return_sequences=num_return_sequences, no_repeat_ngram_size=no_repeat_ngram_size,
        num_beams=num_beams, num_beam_groups=num_beam_groups,
        max_length=max_length, diversity_penalty=diversity_penalty
    )

    res = tokenizer.batch_decode(outputs, skip_special_tokens=True)

    return res

# %%
text = 'An architect is not drawing blueprints for a new building .'
paraphrase(text)
# Out:
# /Users/raunakpandey/Documents/programming/projects/env/lib/python3.8/site-packages/transformers/generation/configuration_utils.py:362: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.7` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# ['The architect is not in charge of creating the blueprints for a new building.',
#  'A new building blueprints are not being prepared by an architect.',
#  'Architects are not in the process of creating blueprints for a new building.',
#  'There is no architect who has designed the blueprints for a new building.',
#  'An architect is refraining from creating plans for a new building.']

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('/Users/raunakpandey/Documents/programming/projects/augmentation/Contradictions.csv')
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0             0           0
# 1             1           1
# 2             2           2
# 3             3           3
# 4             4           4
#
#                                              premise  label  \
# 0             The cat is sleeping on the windowsill.      1
# 1  A group of friends is playing soccer in the park.      1
# 2  The chef is preparing a delicious meal in the ...      1
# 3  A bright rainbow stretches across the sky afte...      1
# 4  The students are listening attentively during ...      1
#
#                                         swap_sub_obj  \
# 0              The windowsill is sleeping on the cat
# 1   A park of friends is playing soccer in the group
# 2  The kitchen is preparing a delicious meal in t...
# 3  A bright rain stretches across the sky after t...
# 4  The lecture are listening attentively during t...
#
#                                             negation  \
# 0        The cat is not sleeping on the windowsill .
# 1  A group of friends is not playing soccer in th...
# 2  The chef is not preparing a delicious meal in ...
# 3  A bright rainbow doesn't stretches across the ...
# 4  The students are not listening attentively dur...
#
#                                       numbers_change  \
# 0            The cat is sleeping on the windowsill .
# 1  A group of friends is playing soccer in the pa...
# 2  The chef is preparing a delicious meal in the ...
# 3  A bright rainbow stretches across the sky afte...
# 4  The students are listening attentively during ...
#
#                                        change_nouns1  \
# 0             The dog is sleeping on the windowsill.
# 1  A grouping of friends is playing soccer in the...
# 2  The cook is preparing a delicious meal in the ...
# 3  A bright anya stretches across the sky after t...
# 4  The students are listening attentively during ...
#
#                                        change_nouns2  \
# 0            The cat is sleeping on the window-sill.
# 1  A group of friends is playing football in the ...
# 2  The chef is preparing a delicious breakfast in...
# 3  A bright rainbow stretches across the cloud af...
# 4  The students are listening attentively during ...
#
#                                         change_verbs
# 0                 The cat is doze on the windowsill.
# 1  A group of friends is understudy soccer in the...
# 2  The chef is de-brief a delicious meal in the k...
# 3  A bright rainbow bicep across the sky after th...
# 4  The students are talk attentively during the l...

# %%
df.drop(['Unnamed: 0'] , axis=1, inplace=True)
df.drop(['Unnamed: 0.1'] , axis=1, inplace=True)

# %% [markdown]
# ## for negations

# %%
def apply_paraphrase(df):
    from tqdm.auto import tqdm
    tqdm.pandas()
    outputs = df['negation'].progress_apply(paraphrase)
    for i in range(5):
        df[f'paraphrase_negations_{i}'] = outputs.apply(lambda x: x[i])
    return df

# %%
df_paraphrased = apply_paraphrase(df)
# Out:
#   0%|          | 0/317 [00:00<?, ?it/s]/Users/raunakpandey/Documents/programming/projects/env/lib/python3.8/site-packages/transformers/generation/configuration_utils.py:362: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.7` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# 100%|██████████| 317/317 [08:25<00:00,  1.59s/it]

# %%
df_paraphrased.head()
# Out:
#                                              premise  label  \
# 0             The cat is sleeping on the windowsill.      1
# 1  A group of friends is playing soccer in the park.      1
# 2  The chef is preparing a delicious meal in the ...      1
# 3  A bright rainbow stretches across the sky afte...      1
# 4  The students are listening attentively during ...      1
#
#                                         swap_sub_obj  \
# 0              The windowsill is sleeping on the cat
# 1   A park of friends is playing soccer in the group
# 2  The kitchen is preparing a delicious meal in t...
# 3  A bright rain stretches across the sky after t...
# 4  The lecture are listening attentively during t...
#
#                                             negation  \
# 0        The cat is not sleeping on the windowsill .
# 1  A group of friends is not playing soccer in th...
# 2  The chef is not preparing a delicious meal in ...
# 3  A bright rainbow doesn't stretches across the ...
# 4  The students are not listening attentively dur...
#
#                                       numbers_change  \
# 0            The cat is sleeping on the windowsill .
# 1  A group of friends is playing soccer in the pa...
# 2  The chef is preparing a delicious meal in the ...
# 3  A bright rainbow stretches across the sky afte...
# 4  The students are listening attentively during ...
#
#                                        change_nouns1  \
# 0             The dog is sleeping on the windowsill.
# 1  A grouping of friends is playing soccer in the...
# 2  The cook is preparing a delicious meal in the ...
# 3  A bright anya stretches across the sky after t...
# 4  The students are listening attentively during ...
#
#                                        change_nouns2  \
# 0            The cat is sleeping on the window-sill.
# 1  A group of friends is playing football in the ...
# 2  The chef is preparing a delicious breakfast in...
# 3  A bright rainbow stretches across the cloud af...
# 4  The students are listening attentively during ...
#
#                                         change_verbs  \
# 0                 The cat is doze on the windowsill.
# 1  A group of friends is understudy soccer in the...
# 2  The chef is de-brief a delicious meal in the k...
# 3  A bright rainbow bicep across the sky after th...
# 4  The students are talk attentively during the l...
#
#                               paraphrase_negations_0  \
# 0       The cat is not slumbering on the windowsill.
# 1  In the park, a group of friends is not engagin...
# 2  The chef is not preparing a tasty meal in the ...
# 3      The sky lacks a clear rainbow after the rain.
# 4  The students are not paying enough attention d...
#
#                               paraphrase_negations_1  \
# 0     But the cat is not sleeping on the windowsill.
# 1  A group of friends is not participating in soc...
# 2  There is no indication that the chef is cookin...
# 3    After the rain, the sky lacks a bright rainbow.
# 4  During the lecture, the students are not payin...
#
#                               paraphrase_negations_2  \
# 0   The cat is no longer residing on the windowsill.
# 1  Rather than playing soccer in the park, a grou...
# 2  A delicious meal is not being prepared by the ...
# 3  A bright rainbow is not visible in the sky aft...
# 4  Students are not paying enough attention durin...
#
#                               paraphrase_negations_3  \
# 0  There is no chance that the cat is sleeping on...
# 1  There are a few friends who are not playing so...
# 2  It appears that the chef is not cooking up a d...
# 3  The rain does not lead to a bright rainbow in ...
# 4    The lecture is being overheard by the students.
#
#                               paraphrase_negations_4
# 0        It's not the cat sleeping on a window sill.
# 1  The park is not the site of a soccer match amo...
# 2  The chef is not cooking a tasty meal in the ki...
# 3  Following the rainfall, a bright rainbow does ...
# 4  Lecture: The students are not paying enough at...

# %% [markdown]
# ## for premise

# %%
def apply_paraphrase(df, column):
    df_new = df.copy()
    from tqdm.auto import tqdm
    tqdm.pandas()
    outputs = df_new[column].progress_apply(paraphrase)
    for i in range(5):
        df_new[f'paraphrase_{column}_{i}'] = outputs.apply(lambda x: x[i])
    return df_new

# %%
df_premise_neg_para = apply_paraphrase(df_paraphrased, 'premise')
# Out:
#   0%|          | 0/317 [00:00<?, ?it/s]/Users/raunakpandey/Documents/programming/projects/env/lib/python3.8/site-packages/transformers/generation/configuration_utils.py:362: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.7` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# 100%|██████████| 317/317 [07:59<00:00,  1.51s/it]

# %%
df_negations_para = apply_paraphrase(df, 'negation')
# Out:
#   0%|          | 0/317 [00:00<?, ?it/s]/Users/raunakpandey/Documents/programming/projects/env/lib/python3.8/site-packages/transformers/generation/configuration_utils.py:362: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.7` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# 100%|██████████| 317/317 [08:34<00:00,  1.62s/it]

# %%
df_negations_para.iloc[:5,-5:]
# Out:
#                               paraphrase_negations_0  \
# 0       The cat is not slumbering on the windowsill.
# 1  In the park, a group of friends is not engagin...
# 2  The chef is not preparing a tasty meal in the ...
# 3      The sky lacks a clear rainbow after the rain.
# 4  The students are not paying enough attention d...
#
#                               paraphrase_negations_1  \
# 0     But the cat is not sleeping on the windowsill.
# 1  A group of friends is not participating in soc...
# 2  There is no indication that the chef is cookin...
# 3    After the rain, the sky lacks a bright rainbow.
# 4  During the lecture, the students are not payin...
#
#                               paraphrase_negations_2  \
# 0   The cat is no longer residing on the windowsill.
# 1  Rather than playing soccer in the park, a grou...
# 2  A delicious meal is not being prepared by the ...
# 3  A bright rainbow is not visible in the sky aft...
# 4  Students are not paying enough attention durin...
#
#                               paraphrase_negations_3  \
# 0  There is no chance that the cat is sleeping on...
# 1  There are a few friends who are not playing so...
# 2  It appears that the chef is not cooking up a d...
# 3  The rain does not lead to a bright rainbow in ...
# 4    The lecture is being overheard by the students.
#
#                               paraphrase_negations_4
# 0        It's not the cat sleeping on a window sill.
# 1  The park is not the site of a soccer match amo...
# 2  The chef is not cooking a tasty meal in the ki...
# 3  Following the rainfall, a bright rainbow does ...
# 4  Lecture: The students are not paying enough at...

# %%
df_paraphrased.to_csv('/Users/raunakpandey/Documents/programming/projects/augmentation/premise_para.csv')

# %%
df_negations_para.to_csv('/Users/raunakpandey/Documents/programming/projects/augmentation/negations_final.csv')

# %% [markdown]
# ## for hypothesis

# %%
df_hypothesis = pd.read_csv("/Users/raunakpandey/Documents/programming/projects/augmentation/cgptsamples-1.csv")

# %%
df_hypothesis.head()
# Out:
#                                              premise  \
# 0             The cat is sleeping on the windowsill.
# 1  A group of friends is playing soccer in the park.
# 2  The chef is preparing a delicious meal in the ...
# 3  A bright rainbow stretches across the sky afte...
# 4  The students are listening attentively during ...
#
#                               hypothesis  label
# 0               The cat is taking a nap.      1
# 1      People are enjoying the outdoors.      1
# 2                A meal is being cooked.      1
# 3                  The rain has stopped.      1
# 4  The teacher is giving a presentation.      1

# %%
df_hypothesis_para = apply_paraphrase(df_hypothesis, 'hypothesis')
# Out:
#   0%|          | 0/317 [00:00<?, ?it/s]/Users/raunakpandey/Documents/programming/projects/env/lib/python3.8/site-packages/transformers/generation/configuration_utils.py:362: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.7` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# 100%|██████████| 317/317 [03:52<00:00,  1.36it/s]

# %%
df_hypothesis_para.head()
# Out:
#                                              premise  \
# 0             The cat is sleeping on the windowsill.
# 1  A group of friends is playing soccer in the park.
# 2  The chef is preparing a delicious meal in the ...
# 3  A bright rainbow stretches across the sky afte...
# 4  The students are listening attentively during ...
#
#                               hypothesis  label  \
# 0               The cat is taking a nap.      1
# 1      People are enjoying the outdoors.      1
# 2                A meal is being cooked.      1
# 3                  The rain has stopped.      1
# 4  The teacher is giving a presentation.      1
#
#                  paraphrase_negations_0  \
# 0  The cat is taking a break for sleep.
# 1     People are fond of being outside.
# 2             A meal is being prepared.
# 3                  The rain has ceased.
# 4            The teacher is presenting.
#
#                            paraphrase_negations_1  \
# 0  Sleeping time: The cat is enjoying a good nap.
# 1       The outdoors are being enjoyed by people.
# 2            The preparation of food is underway.
# 3                   Rainfall is now non-existent.
# 4                       A lecturer is presenting.
#
#                            paraphrase_negations_2  \
# 0                   This is the cat taking a nap.
# 1  Those who like to be outdoors are in the mood.
# 2        Cooking a meal is currently in progress.
# 3            There is no more rain on the ground.
# 4             Teacher: The teacher is presenting.
#
#                       paraphrase_negations_3  \
# 0                          It's sleeping in.
# 1   People have a passion for being outside.
# 2     It is the meal that is being prepared.
# 3                    It has stopped raining.
# 4  There is a presentation from the teacher.
#
#                            paraphrase_negations_4
# 0               The feline is currently sleeping.
# 1  Outdoor activities are favored by many people.
# 2              We are currently preparing a meal.
# 3                        We have ceased the rain.
# 4                  The educator is giving a talk.

# %%
df_hypothesis_para.rename(columns=
    {'paraphrase_negations_0': 'paraphrase_hypothesis_0',
    'paraphrase_negations_1': 'paraphrase_hypothesis_1',
    'paraphrase_negations_2': 'paraphrase_hypothesis_2',
    'paraphrase_negations_3': 'paraphrase_hypothesis_3',
    'paraphrase_negations_4': 'paraphrase_hypothesis_4'}, inplace=True)

# %%
df_hypothesis_para.head()
# Out:
#                                              premise  \
# 0             The cat is sleeping on the windowsill.
# 1  A group of friends is playing soccer in the park.
# 2  The chef is preparing a delicious meal in the ...
# 3  A bright rainbow stretches across the sky afte...
# 4  The students are listening attentively during ...
#
#                               hypothesis  label  \
# 0               The cat is taking a nap.      1
# 1      People are enjoying the outdoors.      1
# 2                A meal is being cooked.      1
# 3                  The rain has stopped.      1
# 4  The teacher is giving a presentation.      1
#
#                 paraphrase_hypothesis_0  \
# 0  The cat is taking a break for sleep.
# 1     People are fond of being outside.
# 2             A meal is being prepared.
# 3                  The rain has ceased.
# 4            The teacher is presenting.
#
#                           paraphrase_hypothesis_1  \
# 0  Sleeping time: The cat is enjoying a good nap.
# 1       The outdoors are being enjoyed by people.
# 2            The preparation of food is underway.
# 3                   Rainfall is now non-existent.
# 4                       A lecturer is presenting.
#
#                           paraphrase_hypothesis_2  \
# 0                   This is the cat taking a nap.
# 1  Those who like to be outdoors are in the mood.
# 2        Cooking a meal is currently in progress.
# 3            There is no more rain on the ground.
# 4             Teacher: The teacher is presenting.
#
#                      paraphrase_hypothesis_3  \
# 0                          It's sleeping in.
# 1   People have a passion for being outside.
# 2     It is the meal that is being prepared.
# 3                    It has stopped raining.
# 4  There is a presentation from the teacher.
#
#                           paraphrase_hypothesis_4
# 0               The feline is currently sleeping.
# 1  Outdoor activities are favored by many people.
# 2              We are currently preparing a meal.
# 3                        We have ceased the rain.
# 4                  The educator is giving a talk.

# %%
df_hypothesis_para.to_csv('/Users/raunakpandey/Documents/programming/projects/augmentation/augmented_data/hypothesis_para.csv')
